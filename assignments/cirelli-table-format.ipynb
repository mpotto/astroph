# %% [markdown]
# # Formatting *Cirelli* table

# %%
import numpy as np
import pandas as pd

# %%
spectras_table = 'spectras/AtProduction_gammas.dat'

# %%
columns= ["$m_{DM}$", "$\log_{10} x$", "$e^L$", "$e^R$", "$e$", "$\mu^L$", "$\mu^R$", "$\mu$", "$\tau^L$", "$\tau^R$", r"$\tau$", r"$q\bar{q}$", r"$c\bar{c}$", r"$b\bar{b}$",
          r"$t\bar{t}$", "$W^L$", "$W^T$", "$W$", "$Z^L$", "$Z^T$", "$Z$", r"$g\bar{g}$", "$\gamma$", r"$h$", "$\nu_e$", r"$\nu_{\mu}$", r"$\nu_{\tau}$", 
          r"$VV \rightarrow 4e$", r"$VV \rightarrow 4\mu$", r"$VV \rightarrow 4\tau$"]

# %%
data = np.loadtxt(spectras_table, skiprows=1)

# %%
spectras = pd.DataFrame(data, columns=columns)

# %%
spectras.tail()
# Out:
#        $m_{DM}$  $\log_{10} x$     $e^L$     $e^R$       $e$   $\mu^L$  \
# 11093  100000.0          -0.20  0.120376  0.164452  0.142414  0.118679
# 11094  100000.0          -0.15  0.114321  0.156519  0.135420  0.112061
# 11095  100000.0          -0.10  0.108509  0.148947  0.128728  0.105200
# 11096  100000.0          -0.05  0.102214  0.140988  0.121601  0.097452
# 11097  100000.0           0.00  0.097123  0.135170  0.116147  0.091384
#
#         $\mu^R$     $\mu$  $\tau^L$  $\tau^R$  ...       $Z$  $g\bar{g}$  \
# 11093  0.162191  0.140435  0.250219  0.343664  ...  0.017353    0.034521
# 11094  0.153479  0.132770  0.180252  0.247822  ...  0.011076    0.020960
# 11095  0.144449  0.124824  0.129938  0.178762  ...  0.006866    0.013063
# 11096  0.134443  0.115948  0.098153  0.135501  ...  0.003653    0.008542
# 11097  0.127185  0.109285  0.084001  0.116918  ...  0.001291    0.006717
#
#         $\gamma$       $h$   $\nu_e$  $\nu_{\mu}$  $\nu_{\tau}$  \
# ...

# %%
spectras.to_pickle('spectras/at-production-gammas.pkl')
